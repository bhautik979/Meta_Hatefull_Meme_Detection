# %% [markdown]
# # Download Kaggle Notebook Output and List Files
# This notebook demonstrates how to download the output of a Kaggle notebook and check the downloaded files using PowerShell commands.

# %%
# 1. Download the notebook output locally
kaggle kernels output muddybuddy/08-training -p ./kaggle-outputs/08-training

# %%
# 2. Check what was downloaded
Get-ChildItem ./kaggle-outputs/08-training
